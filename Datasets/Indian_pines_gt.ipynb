# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayukh-Mondal-Dev/Hybrid-SSRN-Vision-Transformer-Architecture-For-Hyperspectral-Image-Classification/blob/main/Indian_pines_gt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.io
# Load MATLAB file
mat_data = scipy.io.loadmat('Indian_pines_gt.mat')

# Print the variables in the MATLAB file
print("Variables in the MATLAB file:")
for var_name in mat_data:
    if not var_name.startswith("__"):  # Exclude internal variables
        print(var_name)
# Out:
# Variables in the MATLAB file:
# indian_pines_gt

# %%
import scipy.io
import matplotlib.pyplot as plt

# Load MATLAB file
mat_data = scipy.io.loadmat('Indian_pines_gt.mat')

# Assuming the ground truth map is stored in a variable named 'indian_pines_gt'
ground_truth_map = mat_data['indian_pines_gt']
print("Ground truth map shape:", ground_truth_map.shape)

# Visualize the ground truth map
plt.figure()
plt.imshow(ground_truth_map, cmap='jet')  # Assuming categorical labels, using 'jet' colormap
plt.title('Ground Truth Map')
plt.colorbar(label='Class')
plt.axis('off')
plt.show()
# Out:
# Ground truth map shape: (145, 145)
